# %% [markdown]
# ## Imports

# %%
import pandas as pd
from pyjavaproperties import Properties

# %% [markdown]
# ## Settings to enable real-time output from a shell command

# %%
from subprocess import Popen, PIPE, STDOUT
from IPython.core.magic import register_line_magic

@register_line_magic
def runrealcmd(command):
    process = Popen(command, stdout=PIPE, shell=True, stderr=STDOUT, bufsize=1, close_fds=True)
    for line in iter(process.stdout.readline, b''):
        print(line.rstrip().decode('utf-8'))
    process.stdout.close()
    process.wait()

# %% [markdown]
# # 1. Self Join

# %% [markdown]
# ## 1.a Preview the input file

# %%
df = pd.read_csv('../data/dblp_authors_test.csv', sep=';', header=None, names=['Paper_ID', 'Authors'])
df.head()
# Out:
#      Paper_ID                                         Authors
# 0  SIGMOD2014              Dong+Deng,Guoliang+Li,Jianhua+Feng
# 1    ICDE2013  Dong+Deng,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 2   VLDB2016a       Dong+Deng,Guoliang+Li,He+Wen,Jianhua+Feng
# 3  SIGMOD2015           Guoliang+Li,Jian+He,Dong+Deng,Jian+Li
# 4    VLDB2014   Yu+Jiang,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li

# %% [markdown]
# ## 1.b Load and optionally edit the config file

# %%
config_file_example = '../config.properties.example'
config_file = '../config.properties'
input_file = '../data/dblp_authors_test.csv'
output_file = '../data/output/dblp_authors_selfjoin_out.csv'
stats_file = '../data/output/stats.csv'

# %%
params = Properties()
params.load(open(config_file_example))
params.list()
# Out:
# -- listing properties --
# mode=standard
# operation=search
# query_file=data/test_input_R.csv
# input_file=data/test_input_S.csv
# query_id=0
# max_lines=-1
# fuzzyset_column=1
# set_column=2
# tokens_column=3
# column_delimiter=;
# token_delimiter=,
# header=false
# return_counts=true
# output_file=out.txt
# stats_file=stats.txt
# sim_threshold=0.8
# k=3

# %%
params['operation'] = 'self-join'
params['sim_threshold'] = '0.33'
params['input_file'] = input_file
params['output_file'] = output_file
params['stats_file'] = stats_file
params['set_column'] = '1'
params['tokens_column'] = '2'
params['return_counts'] = 'false'

# %%
params.list()
# Out:
# -- listing properties --
# mode=standard
# operation=self-join
# query_file=data/test_input_R.csv
# input_file=../data/dblp_authors_test.csv
# query_id=0
# max_lines=-1
# fuzzyset_column=1
# set_column=1
# tokens_column=2
# column_delimiter=;
# token_delimiter=,
# header=false
# return_counts=false
# output_file=../data/output/dblp_authors_selfjoin_out.csv
# stats_file=../data/output/stats.csv
# sim_threshold=0.33
# k=3

# %%
params.store(open(config_file, 'w'))

# %% [markdown]
# ## 1.c Execute the join operation

# %%
# %runrealcmd java -jar ../target/simjoin-0.0.1-SNAPSHOT-jar-with-dependencies.jar $config_file
# Out:
# Finished reading file. Lines read: 18. Lines skipped due to errors: 0. Num of sets: 18. Elements per set: 3.9444444444444446
# Transform time: 0.017376123 sec.
# Join time: 0.011270184 sec.
# Total Matches: 20

# %% [markdown]
# ## 1.d Load the results

# %%
out1 = pd.read_csv(output_file, header=None, names=['Paper_ID_1', 'Paper_ID_2', 'Similarity'])
out1['Authors_1'] = df.set_index('Paper_ID').Authors[out1.Paper_ID_1].reset_index(drop=True)
out1['Authors_2'] = df.set_index('Paper_ID').Authors[out1.Paper_ID_2].reset_index(drop=True)
out1.sort_values('Similarity', ascending=False).head(20)
# Out:
#      Paper_ID_1   Paper_ID_2  Similarity  \
# 2    SIGMOD2014     ICDE2013    0.750000
# 3     VLDB2016a   SIGMOD2014    0.750000
# 17     VLDB2011  SIGMOD2012b    0.750000
# 16     VLDB2011   SIGMOD2014    0.750000
# 18     VLDB2011     ICDE2013    0.600000
# 7     VLDB2016a     VLDB2011    0.600000
# 8     VLDB2016a     ICDE2013    0.600000
# 14     VLDB2014     ICDE2013    0.600000
# 1    SIGMOD2014  SIGMOD2012b    0.500000
# 0   SIGMOD2012b     ICDE2013    0.400000
# 4     VLDB2016a  SIGMOD2012b    0.400000
# 9    SIGMOD2015   SIGMOD2014    0.400000
# 11     VLDB2014   SIGMOD2014    0.400000
# 12     VLDB2014  SIGMOD2012b    0.400000
# 15     VLDB2011   SIGMOD2015    0.333333
# 10   SIGMOD2015     ICDE2013    0.333333
# 13     VLDB2014     VLDB2011    0.333333
# 6     VLDB2016a     VLDB2014    0.333333
# 5     VLDB2016a   SIGMOD2015    0.333333
# 19     VLDB2018    VLDB2016b    0.333333
#
#                                             Authors_1  \
# 2                  Dong+Deng,Guoliang+Li,Jianhua+Feng
# 3           Dong+Deng,Guoliang+Li,He+Wen,Jianhua+Feng
# 17    Guoliang+Li,Dong+Deng,Jiannan+Wang,Jianhua+Feng
# 16    Guoliang+Li,Dong+Deng,Jiannan+Wang,Jianhua+Feng
# 18    Guoliang+Li,Dong+Deng,Jiannan+Wang,Jianhua+Feng
# 7           Dong+Deng,Guoliang+Li,He+Wen,Jianhua+Feng
# 8           Dong+Deng,Guoliang+Li,He+Wen,Jianhua+Feng
# 14      Yu+Jiang,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 1                  Dong+Deng,Guoliang+Li,Jianhua+Feng
# 0               Jiannan+Wang,Guoliang+Li,Jianhua+Feng
# 4           Dong+Deng,Guoliang+Li,He+Wen,Jianhua+Feng
# 9               Guoliang+Li,Jian+He,Dong+Deng,Jian+Li
# 11      Yu+Jiang,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 12      Yu+Jiang,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 15    Guoliang+Li,Dong+Deng,Jiannan+Wang,Jianhua+Feng
# 10              Guoliang+Li,Jian+He,Dong+Deng,Jian+Li
# 13      Yu+Jiang,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 6           Dong+Deng,Guoliang+Li,He+Wen,Jianhua+Feng
# 5           Dong+Deng,Guoliang+Li,He+Wen,Jianhua+Feng
# 19  Fabian+Fier,Nikolaus+Augsten,Panagiotis+Bouros...
#
#                                           Authors_2
# 2    Dong+Deng,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 3                Dong+Deng,Guoliang+Li,Jianhua+Feng
# 17            Jiannan+Wang,Guoliang+Li,Jianhua+Feng
# 16               Dong+Deng,Guoliang+Li,Jianhua+Feng
# 18   Dong+Deng,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 7   Guoliang+Li,Dong+Deng,Jiannan+Wang,Jianhua+Feng
# 8    Dong+Deng,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 14   Dong+Deng,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 1             Jiannan+Wang,Guoliang+Li,Jianhua+Feng
# 0    Dong+Deng,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 4             Jiannan+Wang,Guoliang+Li,Jianhua+Feng
# 9                Dong+Deng,Guoliang+Li,Jianhua+Feng
# 11               Dong+Deng,Guoliang+Li,Jianhua+Feng
# 12            Jiannan+Wang,Guoliang+Li,Jianhua+Feng
# 15            Guoliang+Li,Jian+He,Dong+Deng,Jian+Li
# 10   Dong+Deng,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 13  Guoliang+Li,Dong+Deng,Jiannan+Wang,Jianhua+Feng
# 6     Yu+Jiang,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 5             Guoliang+Li,Jian+He,Dong+Deng,Jian+Li
# 19    Willi+Mann,Nikolaus+Augsten,Panagiotis+Bouros

# %% [markdown]
# # 2. Self Closest Pairs

# %% [markdown]
# ## 2.a Load and optionally edit the config file

# %%
output_file = '../data/output/dblp_authors_selfclosestpairs_out.csv'

params['operation'] = 'self-closest-pairs'
params['k'] = '5'
params['input_file'] = input_file
params['output_file'] = output_file
params['stats_file'] = stats_file
params['set_column'] = '1'
params['tokens_column'] = '2'
params['return_counts'] = 'false'

# %%
params.store(open(config_file, 'w'))

# %% [markdown]
# ## 2.b Execute the join operation

# %%
# %runrealcmd java -jar ../target/simjoin-0.0.1-SNAPSHOT-jar-with-dependencies.jar $config_file
# Out:
# Finished reading file. Lines read: 18. Lines skipped due to errors: 0. Num of sets: 18. Elements per set: 3.9444444444444446
# Transform time: 0.016934491 sec.
# Candidates: 8 Verified pairs: 8 Final threshold: 0.6
# Join time: 0.013758427 sec.
# Total Matches: 5

# %% [markdown]
# ## 2.c Load the results

# %%
out2 = pd.read_csv(output_file, header=None, names=['Paper_ID_1', 'Paper_ID_2', 'Similarity'])
out2['Authors_1'] = df.set_index('Paper_ID').Authors[out2.Paper_ID_1].reset_index(drop=True)
out2['Authors_2'] = df.set_index('Paper_ID').Authors[out2.Paper_ID_2].reset_index(drop=True)
out2.sort_values('Similarity', ascending=False).head(5)
# Out:
#   Paper_ID_1   Paper_ID_2  Similarity  \
# 0  VLDB2016a   SIGMOD2014        0.75
# 1   VLDB2011  SIGMOD2012b        0.75
# 2   VLDB2011   SIGMOD2014        0.75
# 3   ICDE2013   SIGMOD2014        0.75
# 4   ICDE2013     VLDB2014        0.60
#
#                                          Authors_1  \
# 0        Dong+Deng,Guoliang+Li,He+Wen,Jianhua+Feng
# 1  Guoliang+Li,Dong+Deng,Jiannan+Wang,Jianhua+Feng
# 2  Guoliang+Li,Dong+Deng,Jiannan+Wang,Jianhua+Feng
# 3   Dong+Deng,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 4   Dong+Deng,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
#
#                                        Authors_2
# 0             Dong+Deng,Guoliang+Li,Jianhua+Feng
# 1          Jiannan+Wang,Guoliang+Li,Jianhua+Feng
# 2             Dong+Deng,Guoliang+Li,Jianhua+Feng
# 3             Dong+Deng,Guoliang+Li,Jianhua+Feng
# 4  Yu+Jiang,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li

# %%
out1.sort_values('Similarity', ascending=False).head(20)
# Out:
#      Paper_ID_1   Paper_ID_2  Similarity  \
# 2    SIGMOD2014     ICDE2013    0.750000
# 3     VLDB2016a   SIGMOD2014    0.750000
# 17     VLDB2011  SIGMOD2012b    0.750000
# 16     VLDB2011   SIGMOD2014    0.750000
# 18     VLDB2011     ICDE2013    0.600000
# 7     VLDB2016a     VLDB2011    0.600000
# 8     VLDB2016a     ICDE2013    0.600000
# 14     VLDB2014     ICDE2013    0.600000
# 1    SIGMOD2014  SIGMOD2012b    0.500000
# 0   SIGMOD2012b     ICDE2013    0.400000
# 4     VLDB2016a  SIGMOD2012b    0.400000
# 9    SIGMOD2015   SIGMOD2014    0.400000
# 11     VLDB2014   SIGMOD2014    0.400000
# 12     VLDB2014  SIGMOD2012b    0.400000
# 15     VLDB2011   SIGMOD2015    0.333333
# 10   SIGMOD2015     ICDE2013    0.333333
# 13     VLDB2014     VLDB2011    0.333333
# 6     VLDB2016a     VLDB2014    0.333333
# 5     VLDB2016a   SIGMOD2015    0.333333
# 19     VLDB2018    VLDB2016b    0.333333
#
#                                             Authors_1  \
# 2                  Dong+Deng,Guoliang+Li,Jianhua+Feng
# 3           Dong+Deng,Guoliang+Li,He+Wen,Jianhua+Feng
# 17    Guoliang+Li,Dong+Deng,Jiannan+Wang,Jianhua+Feng
# 16    Guoliang+Li,Dong+Deng,Jiannan+Wang,Jianhua+Feng
# 18    Guoliang+Li,Dong+Deng,Jiannan+Wang,Jianhua+Feng
# 7           Dong+Deng,Guoliang+Li,He+Wen,Jianhua+Feng
# 8           Dong+Deng,Guoliang+Li,He+Wen,Jianhua+Feng
# 14      Yu+Jiang,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 1                  Dong+Deng,Guoliang+Li,Jianhua+Feng
# 0               Jiannan+Wang,Guoliang+Li,Jianhua+Feng
# 4           Dong+Deng,Guoliang+Li,He+Wen,Jianhua+Feng
# 9               Guoliang+Li,Jian+He,Dong+Deng,Jian+Li
# 11      Yu+Jiang,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 12      Yu+Jiang,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 15    Guoliang+Li,Dong+Deng,Jiannan+Wang,Jianhua+Feng
# 10              Guoliang+Li,Jian+He,Dong+Deng,Jian+Li
# 13      Yu+Jiang,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 6           Dong+Deng,Guoliang+Li,He+Wen,Jianhua+Feng
# 5           Dong+Deng,Guoliang+Li,He+Wen,Jianhua+Feng
# 19  Fabian+Fier,Nikolaus+Augsten,Panagiotis+Bouros...
#
#                                           Authors_2
# 2    Dong+Deng,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 3                Dong+Deng,Guoliang+Li,Jianhua+Feng
# 17            Jiannan+Wang,Guoliang+Li,Jianhua+Feng
# 16               Dong+Deng,Guoliang+Li,Jianhua+Feng
# 18   Dong+Deng,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 7   Guoliang+Li,Dong+Deng,Jiannan+Wang,Jianhua+Feng
# 8    Dong+Deng,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 14   Dong+Deng,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 1             Jiannan+Wang,Guoliang+Li,Jianhua+Feng
# 0    Dong+Deng,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 4             Jiannan+Wang,Guoliang+Li,Jianhua+Feng
# 9                Dong+Deng,Guoliang+Li,Jianhua+Feng
# 11               Dong+Deng,Guoliang+Li,Jianhua+Feng
# 12            Jiannan+Wang,Guoliang+Li,Jianhua+Feng
# 15            Guoliang+Li,Jian+He,Dong+Deng,Jian+Li
# 10   Dong+Deng,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 13  Guoliang+Li,Dong+Deng,Jiannan+Wang,Jianhua+Feng
# 6     Yu+Jiang,Guoliang+Li,Jianhua+Feng,Wen+Syan+Li
# 5             Guoliang+Li,Jian+He,Dong+Deng,Jian+Li
# 19    Willi+Mann,Nikolaus+Augsten,Panagiotis+Bouros
