# %% [markdown]
# ## Imports

# %%
import pandas as pd
from pyjavaproperties import Properties

# %% [markdown]
# ## Settings to enable real-time output from a shell command

# %%
from subprocess import Popen, PIPE, STDOUT
from IPython.core.magic import register_line_magic

@register_line_magic
def runrealcmd(command):
    process = Popen(command, stdout=PIPE, shell=True, stderr=STDOUT, bufsize=1, close_fds=True)
    for line in iter(process.stdout.readline, b''):
        print(line.rstrip().decode('utf-8'))
    process.stdout.close()
    process.wait()

# %% [markdown]
# # 1. Self Join

# %% [markdown]
# ## 1.a Preview the input file

# %%
df = pd.read_csv('../data/dblp_authors_papers_test.csv', sep=';', header=None, names=['Authors','Paper_ID','Title'])
df.sort_values('Authors').head(100)
# Out:
#               Authors     Paper_ID  \
# 33            Chen+Li  SIGMOD2010a
# 39            Chen+Li   SIGMOD2013
# 41         Chuan+Xiao     ICDE2009
# 65      Chuitian+Rong     ICDE2017
# 66        Chunbin+Lin     ICDE2017
# 37        Chunbin+Lin   SIGMOD2013
# 0           Dong+Deng   SIGMOD2014
# 3           Dong+Deng     ICDE2013
# 7           Dong+Deng    VLDB2016a
# 25          Dong+Deng     VLDB2011
# 13          Dong+Deng   SIGMOD2015
# 60        Fabian+Fier     VLDB2018
# 49          Feifei+Li  SIGMOD2010b
# 16        Guoliang+Li     VLDB2014
# 11        Guoliang+Li   SIGMOD2015
# 56        Guoliang+Li    VLDB2012b
# 8         Guoliang+Li    VLDB2016a
# 4         Guoliang+Li     ICDE2013
# 1         Guoliang+Li   SIGMOD2014
# 46        Guoliang+Li  SIGMOD2012b
# 24        Guoliang+Li     VLDB2011
# 44     Haichuan+Shang     ICDE2009
# 40       Haiyong+Wang   SIGMOD2013
# 9              He+Wen    VLDB2016a
# 35       Jason+M+Reed  SIGMOD2012a
# 48     Jeffrey+Jestes  SIGMOD2010b
# 36         Jiaheng+Lu   SIGMOD2013
# 12            Jian+He   SIGMOD2015
# 14            Jian+Li   SIGMOD2015
# 68       Jianguo+Wang     ICDE2017
# ..                ...          ...
# 51              Ke+Yi  SIGMOD2010b
# 23        Lijun+Chang     VLDB2017
# 57         Lizhu+Zhou    VLDB2012b
# 20             Lu+Qin     VLDB2017
# 32    Michael+J+Carey  SIGMOD2010a
# 29   Nikolaus+Augsten    VLDB2016b
# 61   Nikolaus+Augsten     VLDB2018
# 54     Nikos+Mamoulis    VLDB2012a
# 30  Panagiotis+Bouros    VLDB2016b
# 52  Panagiotis+Bouros    VLDB2012a
# 62  Panagiotis+Bouros     VLDB2018
# 31      Rares+Vernica  SIGMOD2010a
# 58      Shanshan+Chen    VLDB2012b
# 53            Shen+Ge    VLDB2012a
# 63          Ulf+Leser     VLDB2018
# 69             Wei+Lu     ICDE2017
# 38           Wei+Wang   SIGMOD2013
# 42           Wei+Wang     ICDE2009
# 6         Wen+Syan+Li     ICDE2013
# 18        Wen+Syan+Li     VLDB2014
# 28         Willi+Mann    VLDB2016b
# 70        Xiaoyong+Du     ICDE2017
# 19          Xubo+Wang     VLDB2017
# 43         Xuemin+Lin     ICDE2009
# 21         Xuemin+Lin     VLDB2017
# 34      Yasin+N+Silva  SIGMOD2012a
# 67      Yasin+N+Silva     ICDE2017
# 22         Ying+Zhang     VLDB2017
# 15           Yu+Jiang     VLDB2014
# 50        Zhepeng+Yan  SIGMOD2010b
#
#                                                 Title
# 33  efficient,parallel,set,similarity,joins,using,...
# 39          string,similarity,measures,joins,synonyms
# 41                         top-k,set,similarity,joins
# 65  fast,scalable,distributed,set,similarity,join,...
# 66  fast,scalable,distributed,set,similarity,join,...
# 37          string,similarity,measures,joins,synonyms
# 0   pivotal,prefix,based,filtering,algorithm,strin...
# 3   top-k,string,similarity,search,edit,distance,c...
# 7   efficient,partition,based,method,exact,set,sim...
# 25   pass,join,partition,based,method,similarity,join
# 13  efficient,similarity,join,search,multi,attribu...
# 60  set,similarity,join,mapreduce,experimental,survey
# 49               probabilistic,string,similarity,join
# 16    string,similarity,joins,experimental,evaluation
# 11  efficient,similarity,join,search,multi,attribu...
# 56              seal,spatio,textual,similarity,search
# 8   efficient,partition,based,method,exact,set,sim...
# 4   top-k,string,similarity,search,edit,distance,c...
# 1   pivotal,prefix,based,filtering,algorithm,strin...
# 46  can,we,beat,prefix,filtering,adaptive,framewor...
# 24   pass,join,partition,based,method,similarity,join
# 44                         top-k,set,similarity,joins
# 40          string,similarity,measures,joins,synonyms
# 9   efficient,partition,based,method,exact,set,sim...
# 35         exploiting,mapreduce,based,similarity,join
# 48               probabilistic,string,similarity,join
# 36          string,similarity,measures,joins,synonyms
# 12  efficient,similarity,join,search,multi,attribu...
# 14  efficient,similarity,join,search,multi,attribu...
# 68  fast,scalable,distributed,set,similarity,join,...
# ..                                                ...
# 51               probabilistic,string,similarity,join
# 23  leveraging,set,relations,exact,set,similarity,...
# 57              seal,spatio,textual,similarity,search
# 20  leveraging,set,relations,exact,set,similarity,...
# 32  efficient,parallel,set,similarity,joins,using,...
# 29  empirical,evaluation,set,similarity,join,techn...
# 61  set,similarity,join,mapreduce,experimental,survey
# 54                     spatio,textual,similarity,join
# 30  empirical,evaluation,set,similarity,join,techn...
# 52                     spatio,textual,similarity,join
# 62  set,similarity,join,mapreduce,experimental,survey
# 31  efficient,parallel,set,similarity,joins,using,...
# 58              seal,spatio,textual,similarity,search
# 53                     spatio,textual,similarity,join
# 63  set,similarity,join,mapreduce,experimental,survey
# 69  fast,scalable,distributed,set,similarity,join,...
# 38          string,similarity,measures,joins,synonyms
# 42                         top-k,set,similarity,joins
# 6   top-k,string,similarity,search,edit,distance,c...
# 18    string,similarity,joins,experimental,evaluation
# 28  empirical,evaluation,set,similarity,join,techn...
# 70  fast,scalable,distributed,set,similarity,join,...
# 19  leveraging,set,relations,exact,set,similarity,...
# 43                         top-k,set,similarity,joins
# 21  leveraging,set,relations,exact,set,similarity,...
# 34         exploiting,mapreduce,based,similarity,join
# 67  fast,scalable,distributed,set,similarity,join,...
# 22  leveraging,set,relations,exact,set,similarity,...
# 15    string,similarity,joins,experimental,evaluation
# 50               probabilistic,string,similarity,join
#
# [71 rows x 3 columns]

# %% [markdown]
# ## 1.b Load and optionally edit the config file

# %%
config_file_example = '../config.properties.example'
config_file = '../config.properties'
input_file = '../data/dblp_authors_papers_test.csv'
output_file = '../data/output/dblp_authors_papers_selfjoin_out.csv'
stats_file = '../data/output/stats.csv'

# %%
params = Properties()
params.load(open(config_file_example))
params.list()
# Out:
# -- listing properties --
# mode=standard
# operation=search
# query_file=data/test_input_R.csv
# input_file=data/test_input_S.csv
# query_id=0
# max_lines=-1
# fuzzyset_column=1
# set_column=2
# tokens_column=3
# column_delimiter=;
# token_delimiter=,
# header=false
# return_counts=true
# output_file=out.txt
# stats_file=stats.txt
# sim_threshold=0.8
# k=3

# %%
params['mode'] = 'fuzzy'
params['operation'] = 'self-join'
params['sim_threshold'] = '0.33'
params['input_file'] = input_file
params['output_file'] = output_file
params['stats_file'] = stats_file
params['fuzzyset_column'] = '1'
params['set_column'] = '2'
params['tokens_column'] = '3'
params['return_counts'] = 'false'

# %%
params.store(open(config_file, 'w'))

# %% [markdown]
# ## 1.c Execute the join operation

# %%
# %runrealcmd java -jar ../target/simjoin-0.0.1-SNAPSHOT-jar-with-dependencies.jar $config_file
# Out:
# Finished reading file. Lines read: 71. Lines skipped due to errors: 0. Num of sets: 45. Elements per set: 1.5777777777777777
# |=======================|110%
# Transformation Time: 0.002355695 sec.
# Indexing Time: 0.009736258 sec.
#
# Total Join Time: 0.179284877 sec.
# Signature Generation Time: 0.011779396 sec.
# Check Filter Time: 0.009757591 sec.
# NN Filter Time: 0.002340015 sec.
# Verification Time: 0.14507989 sec.
#
# Check Filter Candidates: 971
# NN Filter Candidates: 356
#
# Total Matches: 219

# %% [markdown]
# ## 1.c Load the results

# %%
out1 = pd.read_csv(output_file, header=None, names=['Author_ID_1', 'Author_ID_2', 'Similarity'])
out1.sort_values(['Similarity'], ascending=False).head(150)
# Out:
#                  Author_ID_1               Author_ID_2  Similarity
# 0                     Wei+Lu              Jianguo+Wang    1.000000
# 20                 Ulf+Leser  Johann+Christoph+Freytag    1.000000
# 27                     Ke+Yi            Jeffrey+Jestes    1.000000
# 29              Jianguo+Wang             Chuitian+Rong    1.000000
# 30                   Jian+Li                   Jian+He    1.000000
# 32                   Shen+Ge            Nikos+Mamoulis    1.000000
# 33                Lizhu+Zhou                    Ju+Fan    1.000000
# 39                    Wei+Lu             Chuitian+Rong    1.000000
# 41             Rares+Vernica           Michael+J+Carey    1.000000
# 47               Xiaoyong+Du              Jianguo+Wang    1.000000
# 66               Zhepeng+Yan                 Feifei+Li    1.000000
# 69               Xiaoyong+Du                    Wei+Lu    1.000000
# 70                Ying+Zhang               Lijun+Chang    1.000000
# 72                Jiaheng+Lu              Haiyong+Wang    1.000000
# 73                    Lu+Qin               Lijun+Chang    1.000000
# 78             Shanshan+Chen                    Jun+Hu    1.000000
# 79               Zhepeng+Yan                     Ke+Yi    1.000000
# 83                     Ke+Yi                 Feifei+Li    1.000000
# 84               Zhepeng+Yan            Jeffrey+Jestes    1.000000
# 22             Shanshan+Chen                Lizhu+Zhou    1.000000
# 43                    Jun+Hu                    Ju+Fan    1.000000
# 86                Ying+Zhang                    Lu+Qin    1.000000
# 17             Shanshan+Chen                    Ju+Fan    1.000000
# 19                Lizhu+Zhou                    Jun+Hu    1.000000
# 12                 Xubo+Wang                    Lu+Qin    1.000000
# 10  Johann+Christoph+Freytag               Fabian+Fier    1.000000
# 8                  Xubo+Wang               Lijun+Chang    1.000000
# 6             Haichuan+Shang                Chuan+Xiao    1.000000
# 16                Ying+Zhang                 Xubo+Wang    1.000000
# 9             Jeffrey+Jestes                 Feifei+Li    1.000000
# ..                       ...                       ...         ...
# 15             Yasin+N+Silva              Jianguo+Wang    0.500000
# 14          Nikolaus+Augsten               Fabian+Fier    0.500000
# 34                Xuemin+Lin                 Xubo+Wang    0.500000
# 36                  Wei+Wang            Haichuan+Shang    0.500000
# 38              Haiyong+Wang               Chunbin+Lin    0.500000
# 13             Yasin+N+Silva             Chuitian+Rong    0.500000
# 40                Willi+Mann          Nikolaus+Augsten    0.500000
# 54              Haiyong+Wang                   Chen+Li    0.500000
# 44                  Wei+Wang              Haiyong+Wang    0.500000
# 11                Xuemin+Lin                    Lu+Qin    0.500000
# 62                  Wei+Wang               Chunbin+Lin    0.419355
# 4                Chunbin+Lin                   Chen+Li    0.400000
# 51             Yasin+N+Silva               Chunbin+Lin    0.384615
# 55                Xuemin+Lin                  Wei+Wang    0.379310
# 49             Shanshan+Chen            Nikos+Mamoulis    0.333333
# 45            Nikos+Mamoulis                Lizhu+Zhou    0.333333
# 24                 Ulf+Leser         Panagiotis+Bouros    0.333333
# 3                    Shen+Ge         Panagiotis+Bouros    0.333333
# 56               Wen+Syan+Li              Jianhua+Feng    0.333333
# 26                Willi+Mann         Panagiotis+Bouros    0.333333
# 28            Nikos+Mamoulis                    Jun+Hu    0.333333
# 5             Nikos+Mamoulis                    Ju+Fan    0.333333
# 59                   Shen+Ge                    Jun+Hu    0.333333
# 77                   Shen+Ge                Lizhu+Zhou    0.333333
# 37         Panagiotis+Bouros            Nikos+Mamoulis    0.333333
# 31                   Shen+Ge                    Ju+Fan    0.333333
# 74              Jiannan+Wang              Jianhua+Feng    0.333333
# 48         Panagiotis+Bouros               Fabian+Fier    0.333333
# 46                   Shen+Ge             Shanshan+Chen    0.333333
# 76         Panagiotis+Bouros  Johann+Christoph+Freytag    0.333333
#
# [87 rows x 3 columns]
